# %%
import datetime
import numpy as np
import pandas as pd
import pandas_datareader.data as web

import seaborn as sns
sns.set_style("darkgrid")
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
stock = 'DPZ'
start = datetime.datetime(2017, 5, 17)
end = datetime.datetime(2019, 9, 19)

# %%
def StockData(ticker, start_date, end_date):
    '''requires pandas datareader (as web) and date time'''
    df = web.DataReader(ticker, 'yahoo', start_date, end_date)
    return df

# %%
dpz = StockData(stock, start, end)
dpz
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-05-17  196.229996  191.419998  196.229996  191.460007   595400.0
# 2017-05-18  195.320007  189.119995  191.259995  194.710007  1097800.0
# 2017-05-19  197.250000  193.550003  195.199997  195.800003   645400.0
# 2017-05-22  198.979996  196.509995  197.470001  198.820007   603600.0
# 2017-05-23  199.750000  198.809998  198.850006  199.250000   488700.0
# 2017-05-24  206.020004  199.479996  199.479996  205.970001  1083000.0
# 2017-05-25  208.300003  205.070007  205.410004  208.039993   878800.0
# 2017-05-26  207.720001  206.649994  207.009995  207.050003   636000.0
# 2017-05-30  208.679993  206.679993  207.000000  208.490005   466700.0
# 2017-05-31  212.050003  208.059998  208.910004  211.720001   739100.0
# 2017-06-01  215.490005  210.880005  213.779999  215.339996   899200.0
# 2017-06-02  219.410004  214.580002  215.690002  218.050003   729000.0
# 2017-06-05  218.210007  216.000000  217.990005  217.100006   449200.0
# 2017-06-06  218.429993  216.169998  217.000000  217.850006   912000.0
# 2017-06-07  218.630005  215.679993  218.509995  218.149994   514000.0
# 2017-06-08  218.580002  216.710007  218.220001  217.880005   410200.0
# 2017-06-09  215.139999  204.630005  213.899994  206.190002  1365300.0
# 2017-06-12  205.929993  201.100006  205.000000  204.070007   905800.0
# 2017-06-13  210.139999  204.360001  204.830002  208.399994   712100.0
# 2017-06-14  212.750000  208.830002  209.419998  210.559998   708900.0
# 2017-06-15  209.910004  206.350006  208.960007  209.559998   438000.0
# 2017-06-16  211.949997  208.929993  209.820007  210.839996  1406700.0
# 2017-06-19  215.869995  211.029999  211.130005  215.729996   919800.0
# 2017-06-20  217.619995  214.009995  215.839996  215.029999   601500.0
# 2017-06-21  216.789993  214.960007  215.570007  216.089996   402700.0
# 2017-06-22  218.429993  215.179993  216.080002  218.089996   571900.0
# 2017-06-23  218.630005  215.699997  217.889999  217.050003   624100.0
# 2017-06-26  221.580002  217.059998  217.520004  218.880005   567300.0
# 2017-06-27  219.440002  213.000000  219.440002  213.139999   620800.0
# 2017-06-28  214.490005  211.270004  213.509995  213.600006   739600.0
# ...                ...         ...         ...         ...        ...
# 2019-08-09  250.979996  243.539993  246.190002  247.830002   586800.0
# 2019-08-12  248.750000  239.479996  247.190002  240.009995   803800.0
# 2019-08-13  243.979996  238.110001  240.289993  240.600006   611100.0
# 2019-08-14  239.160004  235.339996  239.160004  236.199997   702800.0
# 2019-08-15  238.820007  232.020004  236.259995  232.889999   900000.0
# 2019-08-16  235.970001  231.470001  234.570007  234.949997   688400.0
# 2019-08-19  238.820007  229.710007  236.070007  232.020004   671700.0
# 2019-09-06  236.730637
# 2019-09-09  238.575806
# 2019-09-10  242.934418
# 2019-09-11  248.440002
# 2019-09-12  246.789993
# 2019-09-13  245.050003
# 2019-09-16  244.789993
# 2019-09-17  243.539993
# 2019-09-18  245.000000
# 2019-09-19  247.009995
# 2019-09-20  247.619995
#
# [591 rows x 6 columns]

# %%
def PriceDate(stock_df):
    stock_df = stock_df.reset_index()
    stock_df['Price'] = stock_df['Adj Close']
    return stock_df[['Date', 'Price']]

# %%
dpz = PriceDate(dpz)
dpz
# Out:
#           Date       Price
# 0   2017-05-17  187.031097
# 1   2017-05-18  190.205917
# 2   2017-05-19  191.270691
# 3   2017-05-22  194.220856
# 4   2017-05-23  194.640884
# 5   2017-05-24  201.205444
# 6   2017-05-25  203.227570
# 7   2017-05-26  202.260452
# 8   2017-05-30  203.667130
# 9   2017-05-31  206.822418
# 10  2017-06-01  210.358673
# 11  2017-06-02  213.005997
# 12  2017-06-05  212.078003
# 13  2017-06-06  212.810623
# 14  2017-06-07  213.103668
# 15  2017-06-08  212.839951
# 16  2017-06-09  201.420380
# 17  2017-06-12  199.349411
# 18  2017-06-13  204.039169
# 19  2017-06-14  206.153961
# 20  2017-06-15  205.174896
# 21  2017-06-16  206.428116
# 22  2017-06-19  211.215775
# 23  2017-06-20  210.530441
# 24  2017-06-21  211.568237
# 25  2017-06-22  213.526398
# 26  2017-06-23  212.508179
# 27  2017-06-26  214.299866
# 28  2017-06-27  208.679962
# 29  2017-06-28  209.130371
# ..         ...         ...
# 561 2019-08-09  247.183289
# 562 2019-08-12  239.383698
# 563 2019-08-13  239.972168
# 564 2019-08-14  235.583633
# 565 2019-08-15  232.282272
# 566 2019-08-16  234.336899
# 567 2019-08-19  231.414551
# 568 2019-08-20  231.823471
# 569 2019-08-21  230.915848
# 570 2019-08-22  231.244995
# 571 2019-08-23  225.559860
# 572 2019-08-26  227.095840
# 573 2019-08-27  221.869522
# 574 2019-08-28  225.260651
# 575 2019-08-29  224.672180
# 576 2019-08-30  226.248062
# 577 2019-09-03  226.277985
# 578 2019-09-04  238.436172
# 579 2019-09-05  244.191116
# 580 2019-09-06  236.730637
# 581 2019-09-09  238.575806
# 582 2019-09-10  242.934418
# 583 2019-09-11  248.440002
# 584 2019-09-12  246.789993
# 585 2019-09-13  245.050003
# 586 2019-09-16  244.789993
# 587 2019-09-17  243.539993
# 588 2019-09-18  245.000000
# 589 2019-09-19  247.009995
# 590 2019-09-20  247.619995
#
# [591 rows x 2 columns]

# %%
plt.figure(figsize=(14,3))
plt.plot(dpz['Price'])
plt.grid(True)
plt.show()

# %%
def drawdown(df):
    
    drawn_down_list = []
    peak_date = trough_date = df.Date[0]
    peak_price = trough_price = df.Price[0]
    continuing_peak = True
    
    for i in range(1, len(df)):
        date = df.Date[i]
        price = df.Price[i]
        
        if price < trough_price:
            trough_date = date
            trough_price = price
            
        if price > peak_price:
            if continuing_peak == False:
                drawn_down_list.append([peak_date, 
                                        trough_date,
                                        peak_price, 
                                        trough_price, 
                                        trough_date - peak_date, 
                                        peak_price -  trough_price, 
                                        trough_price / peak_price - 1]) 
            continuing_peak = True
            peak_date = date 
            trough_date = date
            peak_price = price
            trough_price = price
        else:
            continuing_peak = False

        if i == len(df) - 1:
            drawn_down_list.append([peak_date, 
                                    trough_date,
                                    peak_price,
                                    trough_price, 
                                    trough_date - peak_date, 
                                    peak_price -  trough_price, 
                                    trough_price / peak_price - 1]) 

    drawn_down_df = pd.DataFrame(drawn_down_list, columns=['Peak Date', 
                                                           'Trough Date',
                                                           'Peak Price',  
                                                           'Trough Price',
                                                           'Drawdown Days', 
                                                           'Drawdown Price', 
                                                           'Drawdown Pct'])

    return drawn_down_df

# %%
drawdown(dpz)
# Out:
#     Peak Date Trough Date  Peak Price  Trough Price Drawdown Days  \
# 0  2017-05-25  2017-05-26  203.227570    202.260452        1 days
# 1  2017-06-02  2017-06-05  213.005997    212.078003        3 days
# 2  2017-06-07  2017-06-12  213.103668    199.349411        5 days
# 3  2017-06-22  2017-06-23  213.526398    212.508179        1 days
# 4  2017-06-26  2017-11-08  214.299866    165.583664      135 days
# 5  2018-01-23  2018-02-08  216.051758    195.388245       16 days
# 6  2018-02-21  2018-03-05  226.836136    216.091125       12 days
# 7  2018-03-20  2018-03-22  228.434097    223.314819        2 days
# 8  2018-03-28  2018-04-02  230.682999    227.280045        5 days
# 9  2018-04-05  2018-04-13  232.576843    227.181412        8 days
# 10 2018-04-19  2018-04-24  237.410080    228.660980        5 days
# 11 2018-04-26  2018-04-30  247.194901    238.435883        4 days
# 12 2018-05-24  2018-05-29  248.802689    242.450470        5 days
# 13 2018-06-07  2018-06-11  268.332886    266.093781        4 days
# 14 2018-06-22  2018-07-30  288.986542    253.425354       38 days
# 15 2018-08-24  2018-08-27  294.481812    294.422546        3 days
# 16 2018-08-30  2019-08-27  297.170135    221.869522      362 days
#
#     Drawdown Price  Drawdown Pct
# 0         0.967117     -0.004759
# 1         0.927994     -0.004357
# 2        13.754257     -0.064543
# 3         1.018219     -0.004769
# 4        48.716202     -0.227327
# 5        20.663513     -0.095641
# 6        10.745010     -0.047369
# 7         5.119278     -0.022410
# 8         3.402954     -0.014752
# 9         5.395432     -0.023198
# 10        8.749100     -0.036852
# 11        8.759018     -0.035434
# 12        6.352219     -0.025531
# 13        2.239105     -0.008345
# 14       35.561188     -0.123055
# 15        0.059265     -0.000201
# 16       75.300613     -0.253392

# %%
drawdown_df = drawdown(dpz)

# %%
fig = plt.figure(figsize=(20,6))
sns.lineplot(dpz['Date'], dpz['Price'])

ax = fig.gca()

for i in range(len(drawdown_df)):
    ax.axvline(drawdown_df['Peak Date'][i], 
               color='green', 
               linestyle='--', 
               lw=1)

for i in range(len(drawdown_df)):
    ax.axvline(drawdown_df['Trough Date'][i], 
               color='red', 
               linestyle='--', 
               lw=1)


plt.title("Domino's Peaks and Troughs", fontsize=16)    
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
